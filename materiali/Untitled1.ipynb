# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
x = np.arange(100000)

# %%
y1 = np.sin(12 * x / 10000 * (2 * np.pi))

# %%
envelope

# %%
plt.plot(x,y1)
plt.show()

# %%
import pandas as pd

wavepath = './wave_env.txt'
skeleton_path = './env_skeleton.txt'
enveloped_path = './enveloped.txt'

enveloped = pd.read_csv(enveloped_path, sep=',', header=None)
skeleton = pd.read_csv(skeleton_path, sep=',', header=None)
wave = pd.read_csv(wavepath, sep=',', header=None)

# %%
wave[2] = skeleton[1]
wave[3] = enveloped[1]

# %%
wave.to_csv('./proc_envelope.csv')
